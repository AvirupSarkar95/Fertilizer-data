# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sea

# %%
data=pd.read_csv("C:\\Users\\Avirup\\Documents\\Python_datasets\\FertilizersProduct.csv",encoding="ISO-8859-1")

# %%
data.head()
# Out:
#    Area Code         Area  Item Code                Item  Element Code  \
# 0          2  Afghanistan       4007  Ammonia, anhydrous          5610
# 1          2  Afghanistan       4007  Ammonia, anhydrous          5610
# 2          2  Afghanistan       4007  Ammonia, anhydrous          5610
# 3          2  Afghanistan       4007  Ammonia, anhydrous          5622
# 4          2  Afghanistan       4007  Ammonia, anhydrous          5622
#
#            Element  Year Code  Year      Unit  Value Flag
# 0  Import Quantity       2011  2011    tonnes   4.49    R
# 1  Import Quantity       2014  2014    tonnes   2.00    R
# 2  Import Quantity       2017  2017    tonnes   2.07    R
# 3     Import Value       2011  2011  1000 US$   2.69    R
# 4     Import Value       2014  2014  1000 US$   1.07    R

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 164468 entries, 0 to 164467
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Area Code     164468 non-null  int64
#  1   Area          164468 non-null  object
#  2   Item Code     164468 non-null  int64
#  3   Item          164468 non-null  object
#  4   Element Code  164468 non-null  int64
#  5   Element       164468 non-null  object
#  6   Year Code     164468 non-null  int64
#  7   Year          164468 non-null  int64
#  8   Unit          164468 non-null  object
#  9   Value         164468 non-null  float64
#  10  Flag          164468 non-null  object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 13.8+ MB

# %%
data2=data.loc[data.Area=='India', :]

# %%
data2.head()
# Out:
#        Area Code   Area  Item Code                Item  Element Code  \
# 65372        100  India       4007  Ammonia, anhydrous          5610
# 65373        100  India       4007  Ammonia, anhydrous          5610
# 65374        100  India       4007  Ammonia, anhydrous          5610
# 65375        100  India       4007  Ammonia, anhydrous          5610
# 65376        100  India       4007  Ammonia, anhydrous          5610
#
#                Element  Year Code  Year    Unit       Value Flag
# 65372  Import Quantity       2002  2002  tonnes  1279348.13   Qm
# 65373  Import Quantity       2003  2003  tonnes   979985.94   Qm
# 65374  Import Quantity       2004  2004  tonnes  1189895.82   Qm
# 65375  Import Quantity       2005  2005  tonnes  1731417.05   Qm
# 65376  Import Quantity       2006  2006  tonnes  1781431.57   Qm

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1514 entries, 65372 to 66885
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     1514 non-null   int64
#  1   Area          1514 non-null   object
#  2   Item Code     1514 non-null   int64
#  3   Item          1514 non-null   object
#  4   Element Code  1514 non-null   int64
#  5   Element       1514 non-null   object
#  6   Year Code     1514 non-null   int64
#  7   Year          1514 non-null   int64
#  8   Unit          1514 non-null   object
#  9   Value         1514 non-null   float64
#  10  Flag          1514 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 141.9+ KB

# %%
data2.describe()
# Out:
#        Area Code    Item Code  Element Code    Year Code         Year  \
# count     1514.0  1514.000000   1514.000000  1514.000000  1514.000000
# mean       100.0  4014.079921   5685.068692  2009.653897  2009.653897
# std          0.0     8.799873    237.650541     4.563617     4.563617
# min        100.0  4001.000000   5157.000000  2002.000000  2002.000000
# 25%        100.0  4005.000000   5610.000000  2006.000000  2006.000000
# 50%        100.0  4014.000000   5622.000000  2010.000000  2010.000000
# 75%        100.0  4022.000000   5910.000000  2014.000000  2014.000000
# max        100.0  4030.000000   5922.000000  2017.000000  2017.000000
#
#               Value
# count  1.514000e+03
# mean   1.113823e+06
# std    3.776348e+06
# min    0.000000e+00
# 25%    4.483950e+02
# 50%    9.066505e+03
# 75%    1.814566e+05
# max    3.063487e+07

# %%
data2.columns
# Out:
# Index(['Area Code', 'Area', 'Item Code', 'Item', 'Element Code', 'Element',
#        'Year Code', 'Year', 'Unit', 'Value', 'Flag'],
#       dtype='object')

# %%
data2=data2.drop(['Area Code','Item Code','Element Code','Year Code'],axis=1)

# %%
data2.head()
# Out:
#         Area                Item          Element  Year    Unit       Value  \
# 65372  India  Ammonia, anhydrous  Import Quantity  2002  tonnes  1279348.13
# 65373  India  Ammonia, anhydrous  Import Quantity  2003  tonnes   979985.94
# 65374  India  Ammonia, anhydrous  Import Quantity  2004  tonnes  1189895.82
# 65375  India  Ammonia, anhydrous  Import Quantity  2005  tonnes  1731417.05
# 65376  India  Ammonia, anhydrous  Import Quantity  2006  tonnes  1781431.57
#
#       Flag
# 65372   Qm
# 65373   Qm
# 65374   Qm
# 65375   Qm
# 65376   Qm

# %% [markdown]
# ## Condition of IMPORTS and EXPORTS in India

# %%
data2['Element'].unique()
# Out:
# array(['Import Quantity', 'Import Value', 'Export Quantity',
#        'Export Value', 'Production', 'Agricultural Use'], dtype=object)

# %%
data2['Element'].value_counts().plot(kind='bar')

# %% [markdown]
# # Most PRODUCTION in India

# %%
prod=data2.loc[data2.Element=='Production', :]

# %%
prod.head()
# Out:
#         Area               Item     Element  Year    Unit     Value Flag
# 65500  India  Ammonium sulphate  Production  2002  tonnes  544400.0   Qm
# 65501  India  Ammonium sulphate  Production  2003  tonnes  600700.0   Qm
# 65502  India  Ammonium sulphate  Production  2004  tonnes  615900.0   Qm
# 65503  India  Ammonium sulphate  Production  2005  tonnes  616900.0   Qm
# 65504  India  Ammonium sulphate  Production  2006  tonnes  634800.0   Qm

# %%
prod['Item'].value_counts()
# Out:
# Ammonium sulphate                                                           16
# Diammonium phosphate (DAP)                                                  16
# Urea                                                                        16
# Calcium ammonium nitrate (CAN) and other mixtures with calcium carbonate    15
# Superphosphates, other                                                      12
# NPK fertilizers                                                             12
# Phosphate rock                                                              10
# Other NP compounds                                                           5
# Superphosphates above 35%                                                    4
# Potassium chloride (muriate of potash) (MOP)                                 3
# Potassium sulphate (sulphate of potash) (SOP)                                3
# Name: Item, dtype: int64

# %% [markdown]
# ## EXPORTS

# %%
expo=data2.loc[data2.Element=='Export Quantity', :]

# %%
expo['Item'].value_counts()
# Out:
# Ammonium nitrate (AN)                                                       16
# Ammonium sulphate                                                           16
# Potassium sulphate (sulphate of potash) (SOP)                               16
# Other potassic fertilizers, n.e.c.                                          16
# Fertilizers n.e.c.                                                          16
# Urea                                                                        16
# Sodium nitrate                                                              16
# Phosphate rock                                                              16
# Other NP compounds                                                          16
# Potassium chloride (muriate of potash) (MOP)                                16
# Ammonia, anhydrous                                                          16
# Other nitrogenous fertilizers, n.e.c.                                       16
# ...

# %%
expo.groupby('Item').Value.sum()
# Out:
# Item
# Ammonia, anhydrous                                                           16925.08
# Ammonium nitrate (AN)                                                       171624.63
# Ammonium sulphate                                                           147752.97
# Calcium ammonium nitrate (CAN) and other mixtures with calcium carbonate       976.71
# Diammonium phosphate (DAP)                                                  114389.53
# Fertilizers n.e.c.                                                           56533.35
# Monoammonium phosphate (MAP)                                                 96527.38
# NPK fertilizers                                                             626753.60
# Other NP compounds                                                           27309.48
# Other nitrogenous fertilizers, n.e.c.                                       378694.82
# Other phosphatic fertilizers, n.e.c.                                         27608.00
# ...

# %%
expo.groupby('Item').Value.agg(['count','max','min','mean'])
# Out:
#                                                     count        max      min  \
# Item
# Ammonia, anhydrous                                     16    2795.63     0.00
# Ammonium nitrate (AN)                                  16   26077.38   809.57
# Ammonium sulphate                                      16   31062.58   145.42
# Calcium ammonium nitrate (CAN) and other mixtur...     13     758.00     0.00
# Diammonium phosphate (DAP)                             14   27435.50     0.42
# Fertilizers n.e.c.                                     16    7903.67   443.88
# Monoammonium phosphate (MAP)                           15   90087.85     0.80
# NPK fertilizers                                        15  107013.03     0.11
# Other NP compounds                                     16   14199.44     9.46
# Other nitrogenous fertilizers, n.e.c.                  16   59610.58  6256.36
# Other phosphatic fertilizers, n.e.c.                   15   13549.00     1.51
# ...

# %%
expo.sort_values(['Item','Value']).reset_index(drop=True)
# Out:
#       Area                                       Item          Element  Year  \
# 0    India                         Ammonia, anhydrous  Export Quantity  2010
# 1    India                         Ammonia, anhydrous  Export Quantity  2003
# 2    India                         Ammonia, anhydrous  Export Quantity  2005
# 3    India                         Ammonia, anhydrous  Export Quantity  2007
# 4    India                         Ammonia, anhydrous  Export Quantity  2002
# ..     ...                                        ...              ...   ...
# 313  India  Urea and ammonium nitrate solutions (UAN)  Export Quantity  2006
# 314  India  Urea and ammonium nitrate solutions (UAN)  Export Quantity  2002
# 315  India  Urea and ammonium nitrate solutions (UAN)  Export Quantity  2003
# 316  India  Urea and ammonium nitrate solutions (UAN)  Export Quantity  2004
# 317  India  Urea and ammonium nitrate solutions (UAN)  Export Quantity  2017
#
#        Unit    Value Flag
# ...

# %%
expo.groupby(['Item']).sum()['Value'].plot.bar()

# %%
plt.figure(figsize=(15,10))
sea.lineplot(x='Year',y='Value',hue="Item",data=expo)

# %% [markdown]
# ## IMPORTS

# %%
impo=data2.loc[data2.Element=='Import Quantity', :]

# %%
expo.groupby('Item').Value.sum()
# Out:
# Item
# Ammonia, anhydrous                                                           16925.08
# Ammonium nitrate (AN)                                                       171624.63
# Ammonium sulphate                                                           147752.97
# Calcium ammonium nitrate (CAN) and other mixtures with calcium carbonate       976.71
# Diammonium phosphate (DAP)                                                  114389.53
# Fertilizers n.e.c.                                                           56533.35
# Monoammonium phosphate (MAP)                                                 96527.38
# NPK fertilizers                                                             626753.60
# Other NP compounds                                                           27309.48
# Other nitrogenous fertilizers, n.e.c.                                       378694.82
# Other phosphatic fertilizers, n.e.c.                                         27608.00
# ...

# %%
impo.groupby(['Item']).sum()['Value'].plot.bar()

# %% [markdown]
# # Most used FERTILIZER by India

# %%
data2['Item'].unique()
# Out:
# array(['Ammonia, anhydrous', 'Ammonium nitrate (AN)', 'Ammonium sulphate',
#        'Calcium ammonium nitrate (CAN) and other mixtures with calcium carbonate',
#        'Diammonium phosphate (DAP)', 'Fertilizers n.e.c.',
#        'Monoammonium phosphate (MAP)', 'NPK fertilizers',
#        'Other nitrogenous fertilizers, n.e.c.', 'Other NP compounds',
#        'Other phosphatic fertilizers, n.e.c.',
#        'Other potassic fertilizers, n.e.c.', 'Phosphate rock',
#        'PK compounds', 'Potassium chloride (muriate of potash) (MOP)',
#        'Potassium nitrate',
#        'Potassium sulphate (sulphate of potash) (SOP)', 'Sodium nitrate',
#        'Superphosphates above 35%', 'Superphosphates, other', 'Urea',
#        'Urea and ammonium nitrate solutions (UAN)'], dtype=object)

# %%
data2['Item'].value_counts()
# Out:
# Urea                                                                        96
# Ammonium sulphate                                                           94
# Diammonium phosphate (DAP)                                                  92
# NPK fertilizers                                                             86
# Phosphate rock                                                              85
# Potassium sulphate (sulphate of potash) (SOP)                               83
# Other NP compounds                                                          81
# Potassium chloride (muriate of potash) (MOP)                                81
# Monoammonium phosphate (MAP)                                                73
# Calcium ammonium nitrate (CAN) and other mixtures with calcium carbonate    69
# Ammonium nitrate (AN)                                                       64
# Fertilizers n.e.c.                                                          64
# ...

# %%
data2['Item'].value_counts().plot(kind='bar')

# %%
data2.groupby(['Item']).sum()['Value'].plot.bar()
